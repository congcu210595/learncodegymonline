# %%
import turtle
t = turtle.Turtle()
turtle.bgcolor("Dodger blue")
t.pensize(3)

t.color("black","yellow")
t.begin_fill()
t.lt(20)
for i in range(2):
    t.rt(110)
    t.fd(250)
    t.rt(70)
    t.fd(150)
t.end_fill()

t.penup()
t.goto(-35,-80)
t.pendown()
t.color("black","red")
t.begin_fill()
for i in range(2):
    t.rt(110)
    t.fd(80)
    t.rt(70)
    t.fd(50)
t.end_fill()

t.penup()
t.home()
t.pendown()
t.lt(20)
t.color("black","orange")
t.begin_fill()
for i in range(2):
    t.lt(110)
    t.fd(160)
    t.lt(70)
    t.fd(150)
t.end_fill()

t.bk(150)
t.rt(20)
t.color("black","pink")
t.begin_fill()
t.lt(130)
t.fd(160)
t.lt(100)
t.fd(160)
t.lt(130)
t.fd(205)
t.end_fill()

t.color("black","blue")
t.begin_fill()
for i in range(2):
    t.rt(90)
    t.fd(250)
    t.rt(90)
    t.fd(205)
t.end_fill()

t.rt(90)
t.fd(250)
t.rt(90)
t.fd(70)
t.rt(180)

t.color("black","green")
t.begin_fill()
for i in range(2):
    t.lt(90)
    t.fd(120)
    t.lt(90)
    t.fd(65)
t.end_fill()

t.penup()
t.goto(250,0)
t.pendown()
t.color("black","green")
t.begin_fill()
t.rt(45)
t.fd(90)
t.rt(135)
t.fd(127.28)
t.rt(135)
t.fd(90)
t.end_fill()


t.penup()
t.goto(250,-63.64)
t.pendown()
t.rt(45)
t.color("black","green")
t.begin_fill()
t.rt(45)
t.fd(100)
t.rt(135)
t.fd(141.42)
t.rt(135)
t.fd(100)
t.end_fill()


t.penup()
t.goto(250,-134.35)
t.pendown()
t.rt(45)
t.color("black","green")
t.begin_fill()
t.rt(45)
t.fd(110)
t.rt(135)
t.fd(155.56)
t.rt(135)
t.fd(110)
t.end_fill()

t.penup()
t.goto(250,-212.13)
t.pendown()
t.rt(45)
t.color("black","red")
t.begin_fill()
t.fd(15)
for i in range(2):
    t.rt(90)
    t.fd(80)
    t.rt(90)
    t.fd(30)
t.end_fill()

t.penup()
t.goto(125,250)
t.pendown()
for i in range(4):
    t.rt(90)
    t.fd(120)
    t.goto(125,250)
t.rt(45)
for i in range(4):
    t.rt(90)
    t.fd(100)
    t.goto(125,250)
t.goto(125,190)
t.lt(45)
t.color("black","yellow")
t.begin_fill()
t.circle(60)
t.end_fill()
